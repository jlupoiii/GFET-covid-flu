# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from matplotlib.lines import Line2D

# %%
# EDIT THESE WITH SPECIFIC FUNCTIONALIZATION DATA

folder_name = "2026-03-02 w1d16 dirac-tracking pyrene-capped pos-ctrl/"
folder_path = "../data_pcb_smu/" + folder_name

# Channels to include (0-based index after the time column)
channels_to_plot = [1, 2, 5, 6, 7, 9, 10, 11, 12, 14, 15]

func_steps = ["Initial", "DDT", "Oligo"]
analyte_steps = ["1aM", "100aM", "10fM", "1pM", "100pM", "10nM", "1uM"]

func_title = "Functionalization Steps with Pyrene-capped Oligos"

analyte_title = "Dirac Shift with Pyrene-capped Oligos"

# %%
# Gathering files

func_files = []
analyte_files = []

print(f"Files in '{folder_name}' dir:", sorted(list(os.listdir(folder_path))))

for filename in sorted(list(os.listdir(folder_path))):
    if filename.split("-")[0][:-1] == "analyte":
        analyte_files.append(filename)
    elif filename.split("-")[0][:-1] == "func":
        func_files.append(filename)
    else:
        print("Skipped filename", filename)

print("Functionalization files (in order):", func_files)
print("Analyte files (in order):", analyte_files)
# Out:
# Files in '2026-03-02 w1d16 dirac-tracking pyrene-capped pos-ctrl/' dir: ['.ipynb_checkpoints', 'analyte1-w1d16-1a.csv', 'analyte2-w1d16-100a.csv', 'analyte3-w1d16-10f.csv', 'analyte4-w1d16-1p.csv', 'analyte5-w1d16-100p.csv', 'analyte6-w1d16-10n.csv', 'analyte7-w1d16-1u.csv', 'func1-w1d16-id.csv', 'func2-w1d16-ddt.csv', 'func3-w1d16-oligo.csv']
# Skipped filename .ipynb_checkpoints
# Functionalization files (in order): ['func1-w1d16-id.csv', 'func2-w1d16-ddt.csv', 'func3-w1d16-oligo.csv']
# Analyte files (in order): ['analyte1-w1d16-1a.csv', 'analyte2-w1d16-100a.csv', 'analyte3-w1d16-10f.csv', 'analyte4-w1d16-1p.csv', 'analyte5-w1d16-100p.csv', 'analyte6-w1d16-10n.csv', 'analyte7-w1d16-1u.csv']

# %%
# plottig functionalizations

pos_dps_func = np.zeros((len(func_steps), len(channels_to_plot)))
# neg_dps = 

for i, path in enumerate(func_files):
    # Load the data (adjust filename)
    df = pd.read_csv(folder_path + path)
    
    # Identify rows that contain Dirac data (DIRAC_SWEEP_IDX is not NaN)
    dirac_rows = df[df["DIRAC_SWEEP_IDX"].notna()].copy()
    
    # Use time from previous row (n-1)
    dirac_rows["TIME_FROM_PREV"] = df["TIME"].shift(1).loc[dirac_rows.index].values
    
    # Collect Dirac voltages for all 16 channels
    channel_cols_to_get = [f"DIRAC_V_FWD_CH{i}" for i in range(16)]

    for j, ch in enumerate(channels_to_plot):
        dirac_vals = list(dirac_rows[channel_cols_to_get[ch]])
        # print(type(dirac_val), list(dirac_val))
        pos_dps_func[i, j] = dirac_vals[-1]


n_rows, n_cols = pos_dps_func.shape
x = np.arange(n_rows)  # x-axis = row index (e.g., time or condition)
plt.figure(figsize=(7, 4))

for col in range(n_cols):
    plt.plot(x, pos_dps_func[:, col], marker='o', label=f'CH {channels_to_plot[col]}')
    
plt.xlabel("Functionalization Step")
plt.ylabel("Dirac Voltage (V)")
plt.xticks(x, func_steps)
plt.grid(True)
plt.legend(ncol=1, fontsize=9, loc="center left", bbox_to_anchor=(1.02, 0.5))
plt.title(func_title)
plt.tight_layout()
plt.show()
plt.close()

# %%
# plottig analyte shifts

pos_dps_analyte = np.zeros((len(analyte_steps), len(channels_to_plot)))
# neg_dps = 

for i, path in enumerate(analyte_files):
    # Load the data (adjust filename)
    df = pd.read_csv(folder_path + path)
    
    # Identify rows that contain Dirac data (DIRAC_SWEEP_IDX is not NaN)
    dirac_rows = df[df["DIRAC_SWEEP_IDX"].notna()].copy()
    
    # Use time from previous row (n-1)
    dirac_rows["TIME_FROM_PREV"] = df["TIME"].shift(1).loc[dirac_rows.index].values
    
    # Collect Dirac voltages for all 16 channels
    channel_cols_to_get = [f"DIRAC_V_FWD_CH{i}" for i in range(16)]

    for j, ch in enumerate(channels_to_plot):
        dirac_vals = list(dirac_rows[channel_cols_to_get[ch]])
        # print(type(dirac_val), list(dirac_val))
        pos_dps_analyte[i, j] = dirac_vals[-1]




# baseline dirac voltage, based on post-oligo measurement (last functionalization step)
baseline_file = func_files[-1]  # last string in the list
df_baseline = pd.read_csv(folder_path + baseline_file)

# Identify Dirac rows in baseline
dirac_rows_base = df_baseline[df_baseline["DIRAC_SWEEP_IDX"].notna()].copy()

# Collect Dirac voltages for channels to plot
channel_cols_base = [f"DIRAC_V_FWD_CH{i}" for i in range(16)]
baseline_vals = []
for ch in channels_to_plot:
    dirac_vals_ch = dirac_rows_base[channel_cols_base[ch]].to_numpy()
    baseline_vals.append(dirac_vals_ch[-1])  # last Dirac value for this channel
baseline_vals = np.array(baseline_vals)




n_rows, n_cols = pos_dps_analyte.shape
x = np.arange(n_rows)  # x-axis = row index (e.g., time or condition)
plt.figure(figsize=(7, 4))

for col in range(n_cols):
    plt.plot(x, pos_dps_analyte[:, col], marker='o', label=f'CH {channels_to_plot[col]}')

    # plt.axhline(y=baseline_vals[col], color=f'C{col}', linestyle='--', alpha=0.7)
    plt.axhline(
        y=baseline_vals[col] + col * 7e-4, # tiny vertical offset (tune to your voltage scale)
        color=f"C{col}",
        linestyle="--"
    )

plt.xlabel("Analyte Concentration")
plt.ylabel("Dirac Voltage (V)")
plt.xticks(x, analyte_steps)
plt.grid(True)
baseline_line = Line2D([0], [0], color='black', linestyle='--', label='Baseline Dirac Pts')
handles, labels = plt.gca().get_legend_handles_labels()
plt.legend(handles=handles + [baseline_line], ncol=1, fontsize=9, loc="center left", bbox_to_anchor=(1.02, 0.5))
plt.title(analyte_title)
plt.tight_layout()
plt.show()


# baseline_vals

# normalized plot

norm_pos_dps_analyte = (pos_dps_analyte - baseline_vals) / baseline_vals * 100

n_rows, n_cols = norm_pos_dps_analyte.shape
x = np.arange(n_rows)
plt.figure(figsize=(7, 4))

for col in range(n_cols):
    plt.plot(x, norm_pos_dps_analyte[:, col], marker='o', label=f'CH {channels_to_plot[col]}')

plt.xlabel("Analyte Concentration")
plt.ylabel("Dirac Shift (%)")
plt.xticks(x, analyte_steps)
plt.grid(True)
plt.legend(ncol=1, fontsize=9, loc="center left", bbox_to_anchor=(1.02, 0.5))
plt.title("Normalized " + analyte_title)
plt.tight_layout()
plt.show()

# %%
channel_to_plot = 1

plt.figure(figsize=(7, 5))

for i, path in enumerate(analyte_files):
    df = pd.read_csv(folder_path + path)

    last_full_sweep_idx = int(df["SWEEP_IDX"].iloc[-1] - 1)

    cols = ["V_GATE", f"I_CH{channel_to_plot}"]
    subset = df.loc[df["SWEEP_IDX"] == last_full_sweep_idx, cols]
    n = len(subset)
    subset = subset[:n//2]


    plt.plot(
        subset["V_GATE"].to_numpy(),
        subset[f"I_CH{channel_to_plot}"].to_numpy() * 1e6,
        # marker="o",
        label=path.split('-')[-1].split('.')[-2]+"M"
    )

plt.xlabel("Gate Voltage (V)")
plt.ylabel("Drain Current (uA)")
plt.title(f"IV Curve Shift During Analyte Detection \n(CH{channel_to_plot})")
plt.legend(fontsize=8)
plt.tight_layout()
plt.show()
plt.close()
