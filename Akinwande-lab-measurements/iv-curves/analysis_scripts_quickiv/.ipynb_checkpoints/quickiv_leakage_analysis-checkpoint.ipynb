# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = "../data_pcb_smu/2026-02-18 new-wafer-1 device characterization/quikciv-paragraf-dp15-allChan-init-comparison.csv"

# %%
f = pd.read_csv(path)

# ====== 2. Extract columns ======
Vg = df["D2__CH2__GATE Voltage"]        # Gate voltage
Id = df["D1__CH1 Current"]              # Drain current (change if needed)
Ig = df["D2__CH2__GATE Current"]        # Gate current

# ====== 3. Plot Gate Voltage vs Drain Current ======
plt.figure()
plt.plot(Vg, Id)
plt.xlabel("Gate Voltage (V)")
plt.ylabel("Drain Current (A)")
plt.title("Gate Voltage vs Drain Current (Id–Vg)")
plt.grid(True)
plt.show()

# ====== 4. Plot Gate Voltage vs Gate Current ======
plt.figure()
plt.plot(Vg, Ig)
plt.xlabel("Gate Voltage (V)")
plt.ylabel("Gate Current (A)")
plt.title("Gate Voltage vs Gate Current (Ig–Vg)")
plt.grid(True)
plt.show()
# Out:
# Index(['Repeat', 'VAR2', 'Point', 'D1__CH1 Voltage', 'D1__CH1 Current',
#        'D1__CH1 Resistance', 'D1__CH1 Time', 'D1__CH2 Voltage',
#        'D1__CH2 Current', 'D1__CH2 Resistance', 'D1__CH2 Time',
#        'D2__CH1 Voltage', 'D2__CH1 Current', 'D2__CH1 Resistance',
#        'D2__CH1 Time', 'D2__CH2__GATE Voltage', 'D2__CH2__GATE Current',
#        'D2__CH2__GATE Time'],
#       dtype='object')
